# %%
def reverse_string(s):
    if len(s) == 0 : # boundary condition
        print('String is empty')

    words = s.split()
    for n in range(len(words)):
        print(words[len(words) - n -1], end = ' ')

    # print('s is', s)

# %%
reverse_string('My name is Joe')
# Out:
# Joe is name My
