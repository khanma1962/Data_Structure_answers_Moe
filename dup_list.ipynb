# %%
some_list = [ 'a', 'c', 'a', 'b', 'd', 'c']
some_list
# Out:
# ['a', 'c', 'a', 'b', 'd', 'c']

# %%
def dup_list(s):
    dup = []
    for i in some_list:
        if (some_list.count(i) > 1) and (i not in dup):
            dup.append(i)  
    return dup

if __name__ == '__main__':
    res = dup_list(some_list)
    print(res)
# Out:
# ['a', 'c']

# %%
def dup_list(s):
    dup = []
    for i in some_list:
        if some_list.count(i) > 1:
            dup.append(i)  
    return set(dup)

if __name__ == '__main__':
    res = dup_list(some_list)
    print(res)
# Out:
# {'c', 'a'}

# %%
some_list.count('a')
# Out:
# 2

# %%
def dup_list(s):
    d = {}
    for i in some_list:
        if d.get(i, 0):
            print(i)
        else:
            d[i] = i
    print(d)    

if __name__ == '__main__':
    dup_list(some_list)
# Out:
# a
# c
# {'a': 'a', 'c': 'c', 'b': 'b', 'd': 'd'}

# %%
def dup_list(s):
    d = {}
    for i in some_list:
        # print(i)
        if i in d:
            print(i)
        else:
            d[i] = i
    print(d)    

if __name__ == '__main__':
    dup_list(some_list)
# Out:
# a
# c
# {'a': 'a', 'c': 'c', 'b': 'b', 'd': 'd'}
