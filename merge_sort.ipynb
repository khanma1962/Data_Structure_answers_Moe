# %%
# Spder environment

# print('Array at 2',arr1[2])

# def merge_sorted_array(a, b):
#     x = a + b
#     # print('x is ', x)
#     x.sort()
#     return x
# print('The merged array is ',merge_sorted_array(arr1, arr2))
def merge_sorted_array2(a, b):
    if len(a) < 1 and len(b) < 1: # boundary condition
        return a+b   
    i, j = 0, 0
    sorted_list = []
    while i < len(a) and j < len(b):
        print('comparing i an j', i, j)
        if a[i] < b[j]:
            sorted_list.append(a[i])
            i += 1
        elif b[j] < a[i]:
            sorted_list.append(b[j])
            j += 1
        print('sorted_list -',  sorted_list)
    # print('a[i] is ', i)
    # print('b[j] is ', j)        
    return sorted_list+ a[i:] + b[j:]

# %%
arr1 = [1, 2, 5, 7, 9]
arr2 = [4,6,11,13]
print('The merged array is ',merge_sorted_array2(arr1, arr2))
# Out:
# comparing i an j 0 0
# sorted_list - [1]
# comparing i an j 1 0
# sorted_list - [1, 2]
# comparing i an j 2 0
# sorted_list - [1, 2, 4]
# comparing i an j 2 1
# sorted_list - [1, 2, 4, 5]
# comparing i an j 3 1
# sorted_list - [1, 2, 4, 5, 6]
# comparing i an j 3 2
# sorted_list - [1, 2, 4, 5, 6, 7]
# comparing i an j 4 2
# sorted_list - [1, 2, 4, 5, 6, 7, 9]
# The merged array is  [1, 2, 4, 5, 6, 7, 9, 11, 13]
